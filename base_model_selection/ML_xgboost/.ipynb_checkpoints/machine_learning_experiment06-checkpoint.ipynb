# %%
import os
from glob import glob
import hashlib
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from copy import deepcopy
import ipynbname
import matplotlib.pyplot as plt
import shap
from datetime import datetime
import re

# Constants
EXPERIMENT_NAME = "nursing_home"
DATA_PATH = f"..{os.sep}data{os.sep}"

# %%
current_time = datetime.now()
print("Current time is:",current_time)

nb_fname = ipynbname.name()
print("File:",nb_fname)

experiment_number = int(re.findall(r'\d+', nb_fname)[0])
print(f"Experiment Number: {experiment_number}")  # Output: 01
# Out:
# Current time is: 2024-12-05 10:15:26.290590
# File: machine_learning_experiment01
# Experiment Number: 1

# %%
# Function to generate a consistent hash number for a given file name
def generate_hash_number(file_name):
    """
    Generates a consistent hash number based on the file name.
    
    Args:
        file_name (str): The file name to hash.
    
    Returns:
        int: A 32-bit hash number.
    """
    # Create an MD5 hash object
    hash_obj = hashlib.md5()
    
    # Update the hash object with the file name, encoded to bytes
    hash_obj.update(file_name.encode())

    # Convert the hash to an integer and ensure the range fits 32-bit
    return int(hash_obj.hexdigest(), 16) % (2**32)

# Generate experiment seed from experiment name
initial_seed = generate_hash_number(EXPERIMENT_NAME)
print(f"Experiment Name: {EXPERIMENT_NAME}, Initial Seed: {initial_seed}")
# Out:
# Experiment Name: nursing_home, Initial Seed: 127573839

# %%
# Set the seed for reproducibility
np.random.seed(initial_seed)

# Generate a list of 5 random integers in the range of 32-bit integers
random_integers_list = np.random.randint(low=0, high=2**31 - 1, size=10).tolist()
print("Random Integers List:", random_integers_list)
seed = random_integers_list[experiment_number-1]
# Load clinical microbiome data
df_path = glob(f'{DATA_PATH}*clinical_microbiome_df*')[0]
print(f"Data File Path: {df_path}")

clinical_microbiome_df = pd.read_csv(df_path)
print("Clinical Microbiome Data Loaded.")

# Display value counts for the 'Alzheimers' column
alzheimers_counts = clinical_microbiome_df['Alzheimers'].value_counts()
alzheimers_counts_normalized = clinical_microbiome_df['Alzheimers'].value_counts(normalize=True)

print("Alzheimers Counts:\n", alzheimers_counts)
print("Normalized Alzheimers Counts:\n", alzheimers_counts_normalized)
print(f"Seed in this experiment: {seed}")
# Out:
# Random Integers List: [315491657, 135304577, 1572185508, 1029933563, 1950160822, 563269619, 1573902777, 513873336, 442822283, 1770168448]
# Data File Path: ..\data\clinical_microbiome_df.csv
# Clinical Microbiome Data Loaded.
# Alzheimers Counts:
#  Alzheimers
# 0.0    225
# 1.0    110
# Name: count, dtype: int64
# Normalized Alzheimers Counts:
#  Alzheimers
# 0.0    0.671642
# 1.0    0.328358
# Name: proportion, dtype: float64
# Seed in this experiment: 315491657

# %%
clinical_microbiome_df["Dementia Other"].value_counts()
# Out:
# Dementia Other
# 0    335
# Name: count, dtype: int64

# %%
clinical_microbiome_df = clinical_microbiome_df[clinical_microbiome_df["Dementia Other"] != 1]
# Display value counts for the 'Alzheimers' column
alzheimers_counts = clinical_microbiome_df['Alzheimers'].value_counts()
alzheimers_counts_normalized = clinical_microbiome_df['Alzheimers'].value_counts(normalize=True)
print("Alzheimers Counts:\n", alzheimers_counts)
print("Normalized Alzheimers Counts:\n", alzheimers_counts_normalized)
# Out:
# Alzheimers Counts:
#  Alzheimers
# 0.0    225
# 1.0    110
# Name: count, dtype: int64
# Normalized Alzheimers Counts:
#  Alzheimers
# 0.0    0.671642
# 1.0    0.328358
# Name: proportion, dtype: float64

# %%
clinical_summaries_df = pd.read_csv(glob(f"..{os.sep}data{os.sep}clinical_summaries_df*")[0])
clinical_summaries_df
# Out:
#                   Feature                                        Description  \
# 0               Sample ID  Unique identifier for biological or clinical s...
# 1                study_id  Identifier for the specific study or research ...
# 2                     day          Day of data collection or relevant event.
# 3             Date Sample                Date when the sample was collected.
# 4                     age                            Age of the participant.
# ..                    ...                                                ...
# 98   Severe Liver disease                  Advanced liver disease diagnosis.
# 99                 ostomy                             Presence of an ostomy.
# 100            Alzheimers                  Diagnosis of Alzheimer’s disease.
# 101        Dementia Other                           Other forms of dementia.
# 102            Parkinsons                     Parkinson’s disease diagnosis.
#
#        Group Characteristics  \
# 0       Study Identification
# 1       Study Identification
# 2       Temporal Information
# 3       Temporal Information
# 4    Demographic Information
# ..                       ...
# 98         Hepatic Condition
# 99          Surgical History
# 100   Neurological Condition
# 101   Neurological Condition
# 102   Neurological Condition
#
#                                                Summary
# 0    ### Clinical Feature Summary\n\n#### Feature: ...
# 1    ### Clinical Feature Definitions, Scope, and R...
# 2    ### Clinical Feature Summary for Alzheimer's D...
# 3    ### Clinical Feature Summary\n\n#### Feature: ...
# 4    ### Clinical Feature Summary: Age\n\n**Definit...
# ..                                                 ...
# 98   ### Clinical Feature: Severe Liver Disease\n\n...
# 99   ### Clinical Feature: Ostomy\n\n**Definition:*...
# 100  ### Clinical Feature Summary: Alzheimer's Dise...
# 101  ### Clinical Feature: Dementia Other\n\n**Defi...
# 102  ### Clinical Feature: Parkinson's Disease\n\n*...
#
# [103 rows x 4 columns]

# %%
clinical_summaries_df['Feature'].tolist()[:5]
# Out:
# ['Sample ID', 'study_id', 'day', 'Date Sample', 'age']

# %%
clinical_summaries_df[['Feature']][clinical_summaries_df['Feature'].str.startswith(('c', 'C'))]
# Out:
#                                               Feature
# 10                             clinical_frailty_scale
# 16                          cholinesterase inhibitors
# 17                           Calcium-channel blockers
# 58                         Calcium Channel Modulators
# 59                       Carbonic Anhydrase Inhibitor
# 60                                       Carboxamides
# 71                            Chemotherapy Medication
# 81                                               COPD
# 86                           Congestive heart failure
# 88  Cerebrovascular disease: CVA with mild or no r...
# 89                          Chronic pulmonary disease
# 90                          Connective tissue disease

# %%
bacteria_df = pd.read_csv(glob(f"..{os.sep}data{os.sep}bacteria_df*")[0])
bacteria_df.species_name.tolist()[:5]
# Out:
# ['Faecalibacterium_prausnitzii',
#  'Fusicatenibacter_saccharivorans',
#  'Eubacterium_siraeum',
#  'Gemmiger_formicilis',
#  'Eubacterium_rectale']

# %%
set(bacteria_df.species_name.tolist()[:5])
# Out:
# {'Eubacterium_rectale',
#  'Eubacterium_siraeum',
#  'Faecalibacterium_prausnitzii',
#  'Fusicatenibacter_saccharivorans',
#  'Gemmiger_formicilis'}

# %%
clinical_microbiome_df["Dementia Other"].value_counts()
# Out:
# Dementia Other
# 0    335
# Name: count, dtype: int64

# %%
import os
from math import ceil
from pynvml import nvmlInit, nvmlDeviceGetCount

# Function to get the number of GPUs available
def get_num_gpus():
    try:
        nvmlInit()
        return nvmlDeviceGetCount()
    except Exception as e:
        print(f"Error accessing NVML: {e}")
        return 0

# Function to list all .ipynb files in the current directory
def get_notebook_files():
    return [f for f in os.listdir('.') if f.endswith('.ipynb')]

# Function to evenly distribute files across GPUs
def distribute_files_evenly(files, num_gpus):
    """
    Distributes files evenly across all available GPUs.
    
    Args:
        files (list): List of file names to distribute.
        num_gpus (int): Number of GPUs available.
        
    Returns:
        dict: Distribution of files per GPU.
    """
    distribution = {f"cuda:{i}": [] for i in range(num_gpus)}
    for idx, file in enumerate(files):
        # Assign each file to a GPU in round-robin fashion
        gpu_id = idx % num_gpus
        distribution[f"cuda:{gpu_id}"].append(file)
    return distribution

# Function to get GPU ID for a specific notebook file
def get_gpu_for_file(nb_fname, file_distribution):
    """
    Finds the GPU ID for a given notebook file based on the distribution.
    
    Args:
        nb_fname (str): Notebook file name to find the GPU for.
        file_distribution (dict): Distribution of files per GPU.
    
    Returns:
        str: GPU ID (e.g., "cuda:0") or "Unassigned" if the file is not found.
    """
    for gpu, files in file_distribution.items():
        if nb_fname in files:
            return gpu
    return "cpu"

# Main logic for the notebook
def assign_notebooks_to_gpus():
    # Get the number of GPUs
    num_gpus = get_num_gpus()
    if num_gpus == 0:
        print("No GPUs available. Using CPU for all tasks.")
        return {"cpu": get_notebook_files()}
    
    # Get the list of .ipynb files
    notebook_files = get_notebook_files()
    if not notebook_files:
        print("No .ipynb files found in the current directory.")
        return {}
    
    # Evenly distribute files across GPUs
    file_distribution = distribute_files_evenly(notebook_files, num_gpus)
    
    # Display the distribution in the notebook
    for gpu, files in file_distribution.items():
        print(f"{gpu}: {files}")
    
    return file_distribution

# Run the assignment logic
file_distribution = assign_notebooks_to_gpus()

# Get the GPU ID for the specific notebook file
device = get_gpu_for_file(f"{nb_fname}.ipynb", file_distribution)

print(f"Initial seed: {initial_seed}")
print(f"Random Integers List: {random_integers_list}")
# Print the result
print(f"Notebook '{nb_fname}.ipynb' is assigned to device: {device} with seed {seed}.")
# Out:
# cuda:0: ['machine_learning_experiment01.ipynb', 'machine_learning_experiment02.ipynb', 'machine_learning_experiment03.ipynb', 'machine_learning_experiment04.ipynb', 'machine_learning_experiment05.ipynb', 'machine_learning_experiment06.ipynb', 'machine_learning_experiment07.ipynb', 'machine_learning_experiment08.ipynb', 'machine_learning_experiment09.ipynb', 'machine_learning_experiment10.ipynb']
# Initial seed: 127573839
# Random Integers List: [315491657, 135304577, 1572185508, 1029933563, 1950160822, 563269619, 1573902777, 513873336, 442822283, 1770168448]
# Notebook 'machine_learning_experiment01.ipynb' is assigned to device: cuda:0 with seed 315491657.

# %%
import optuna
from optuna.samplers import TPESampler
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import (
    roc_curve, roc_auc_score, f1_score, accuracy_score, confusion_matrix, 
    classification_report, ConfusionMatrixDisplay
)

from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
from sklearn.model_selection import train_test_split
from copy import deepcopy
from sklearn.preprocessing import StandardScaler

# Constants and Configuration
print(f"Experiment number: {experiment_number} | Seed number: {seed}")
# seed = experiment_seed  # Replace with your experiment seed
test_size = 0.25
gpu_device = "hist"

# Function to check for overlaps between train and test data
def check_for_overlap(train_data, test_data):
    """
    Checks for overlapping Sample ID and study_id between train and test datasets.
    """
    # Check for overlapping Study IDs
    overlap_study_ids = set(train_data["study_id"]) & set(test_data["study_id"])
    if overlap_study_ids:
        print(f"Overlap Study ID found: {overlap_study_ids}")
    else:
        print("No overlap Study ID found.")

    # Check for overlapping Sample IDs
    overlap_sample_ids = set(train_data["Sample ID"]) & set(test_data["Sample ID"])
    if overlap_sample_ids:
        print(f"Overlap Sample ID found: {overlap_sample_ids}")
    else:
        print("No overlap Sample ID found.")

def check_for_bacteria(list_a, list_b):
    """
    Checks for overlapping bactertia from list_a and list list_b database and predicted bacteria.
    """
    # Check for overlapping Study IDs
    list_a = [item.replace(" ", "_") for item in list_a]
    list_b = [item.replace(" ", "_") for item in list_b]
    
    overlap_bacteria = set(list_a) & set(list_b)
    if overlap_bacteria:
        print(f"Overlap bacteria found: {overlap_bacteria}")
    else:
        print("No overlap bacteria found.")
    return overlap_bacteria

        
def preprocess_data(df, columns_to_drop, test_size, seed):
    # Split study IDs into train/test sets
    study_labels = df.groupby("study_id")["Alzheimers"].max().reset_index()
    train_ids, test_ids = train_test_split(
        study_labels["study_id"],
        test_size=test_size,
        stratify=study_labels["Alzheimers"],
        random_state=seed,
    )
    
    train_data = df[df["study_id"].isin(train_ids)].copy()
    test_data = df[df["study_id"].isin(test_ids)].copy()

    # Check for overlaps
    check_for_overlap(train_data, test_data)
    
    # Select feature columns
    feature_columns = [col for col in df.columns if col not in columns_to_drop]

    # Convert feature columns to float64 to ensure compatibility
    train_data[feature_columns] = train_data[feature_columns].astype(np.float64)
    test_data[feature_columns] = test_data[feature_columns].astype(np.float64)

    # Normalize the feature columns
    scaler = StandardScaler()
    train_data.loc[:, feature_columns] = scaler.fit_transform(train_data[feature_columns])
    test_data.loc[:, feature_columns] = scaler.transform(test_data[feature_columns])

    return train_data, test_data, feature_columns

# Function to compute class weights
def compute_weights(y_train):
    class_weights = compute_class_weight("balanced", classes=np.unique(y_train), y=y_train)
    scale_pos_weight = class_weights[1] / class_weights[0]
    return scale_pos_weight

# Define Optuna Objective Function
def objective(trial, X_train, y_train, scale_pos_weight, seed):
    print(f"Seed in the model {seed} on Device {device}")
    # Feature selection parameters
    threshold = trial.suggest_categorical('threshold', ['median', 'mean', '0.5*mean', '1.5*mean', 'very_low'])
    max_features = trial.suggest_int('max_features', 1, X_train.shape[1])
    norm_order = trial.suggest_int('norm_order', 1, 2)
    threshold_value = -1e10 if threshold == 'very_low' else threshold

    # Feature selection
    selector = SelectFromModel(
        estimator=XGBClassifier(
            objective='binary:logistic',
            eval_metric='logloss',
            scale_pos_weight= scale_pos_weight,
            random_state=seed,
            tree_method=gpu_device, 
            device=device
        ),
        threshold=threshold_value,
        max_features=max_features,
        norm_order=norm_order
    )
    
    selector.fit(X_train, y_train)
    X_train_selected = selector.transform(X_train)

    # Define XGBoost parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.5),
        'max_depth': trial.suggest_int('max_depth', 3, 30),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'scale_pos_weight': scale_pos_weight,
        'seed': seed,
        'tree_method': gpu_device,
        'device': device
    }

    # Cross-validation
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=seed)
    f1_scores = []
    for train_idx, val_idx in skf.split(X_train_selected, y_train):
        X_train_fold, X_val_fold = X_train_selected[train_idx], X_train_selected[val_idx]
        y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]
        dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
        dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
        model = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=trial.suggest_int("n_estimators", 50, 300),
            evals=[(dtrain, 'train'), (dval, 'eval')],
            early_stopping_rounds=50,
            verbose_eval=False
        )
        y_val_pred = model.predict(dval)
        y_val_pred_binary = (y_val_pred >= 0.5).astype(int)
        f1_scores.append(f1_score(y_val_fold, y_val_pred_binary))
    return np.mean(f1_scores)

# Main Program
columns_to_drop = ["Sample ID", "study_id", "Alzheimers", "Date Sample", "age", "Dementia Other"] # "malnutrition_indicator_sco", "clinical_frailty_scale", "PPI", 

train_data, test_data, feature_columns = preprocess_data(clinical_microbiome_df, columns_to_drop, test_size, seed)
X_train = deepcopy(train_data[feature_columns].values)
y_train = np.array(train_data["Alzheimers"].values)
X_test = deepcopy(test_data[feature_columns].values)
y_test = np.array(test_data["Alzheimers"].values)
scale_pos_weight = compute_weights(y_train)

# Run Optuna Optimization
study = optuna.create_study(direction="maximize", sampler=TPESampler(seed=seed))
study.optimize(lambda trial: objective(trial, X_train, y_train, scale_pos_weight, seed), n_trials=100)

# Best Parameters
best_params = study.best_params
print("Best Parameters:", best_params)

# Apply Final Model
final_selector = SelectFromModel(
    estimator=XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',
        random_state=seed,
        tree_method=gpu_device,
        device=device,
        scale_pos_weight=scale_pos_weight
    ),
    
    threshold=-1e10 if best_params['threshold'] == 'very_low' else best_params['threshold'],
    max_features=best_params['max_features'],
    norm_order=best_params['norm_order']
)

final_selector.fit(X_train, y_train)
X_train_selected = final_selector.transform(X_train)
X_test_selected = final_selector.transform(X_test)

# Train Final Model
final_model_params = {
    **{k: v for k, v in best_params.items() if k not in ['threshold', 'norm_order', 'max_features', 'n_estimators']},
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'scale_pos_weight': scale_pos_weight,
    'seed': seed,
    'tree_method': gpu_device,
    'device': device
}

dtrain_final = xgb.DMatrix(X_train_selected, label=y_train)
dtest_final = xgb.DMatrix(X_test_selected)

final_model = xgb.train(
    params=final_model_params,
    dtrain=dtrain_final,
    num_boost_round=best_params['n_estimators'],
)

# Predictions and Evaluation
y_test_pred = final_model.predict(dtest_final)
y_test_pred_binary = (y_test_pred >= 0.5).astype(int)
auc = roc_auc_score(y_test, y_test_pred)
accuracy = accuracy_score(y_test, y_test_pred_binary)
f1 = f1_score(y_test, y_test_pred_binary)
conf_matrix = confusion_matrix(y_test, y_test_pred_binary)

print("\nTest Metrics:")
print(f"ROC AUC: {auc}\nAccuracy: {accuracy}\nF1 Score: {f1}\nConfusion Matrix:\n{conf_matrix}")
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["Negative", "Positive"])
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

report = classification_report(y_test, y_test_pred_binary, target_names=["Negative", "Positive"])
print("\nClassification Report:")
print(report)

# Extract feature names for selected features
selected_feature_names = [feature_columns[i] for i in final_selector.get_support(indices=True)]
print(f"Number of selected features: {len(selected_feature_names)}")

# Step 1: Initialize SHAP explainer
explainer = shap.Explainer(final_model, X_train_selected)

# Step 2: Compute SHAP values
shap_values = explainer(X_train_selected, check_additivity=False)

# Ensure SHAP values are in the correct shape for processing
print(f"Shape of SHAP values: {shap_values.values.shape}")  # Check the shape

# Truncate each feature name to a maximum of 30 characters
max_len = 40
selected_feature_names = [
    feature[:max_len] if len(feature) > max_len else feature  # Truncate if longer than 30 characters
    for feature in selected_feature_names
]

# Verify the selected feature names align with the SHAP values
assert len(selected_feature_names) == X_train_selected.shape[1], "Mismatch in feature names and SHAP input dimensions."

# Generate SHAP summary plot with corrected feature names
plt.figure(figsize=(20, 10))  # Increased width for a wider plot
plt.title("SHAP Violin Plot - Global Feature Importance", fontsize=14)

# Create summary plot with corrected feature names
shap.summary_plot(
    shap_values.values,  # SHAP values
    X_train_selected,  # Input data
    feature_names=selected_feature_names,  # Correct feature names
    max_display=20,  # Limit to top 20 features
    plot_type="violin"  # Violin plot with colors
)
plt.show()

bacteria_fount = check_for_bacteria(bacteria_df.species_name.tolist(),selected_feature_names)
# Out:
# Experiment number: 1 | Seed number: 315491657
# No overlap Study ID found.
# No overlap Sample ID found.
# [I 2024-12-05 10:27:22,454] A new study created in memory with name: no-name-8b0f365f-3a26-4341-aaa9-73f233a9ad49
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:23,301] Trial 0 finished with value: 0.7160028555775074 and parameters: {'threshold': 'mean', 'max_features': 730, 'norm_order': 2, 'learning_rate': 0.22784462951868784, 'max_depth': 22, 'min_child_weight': 4, 'subsample': 0.8933027395291244, 'colsample_bytree': 0.7141781976236643, 'gamma': 2.4005160139028456, 'reg_alpha': 9.635155887531152, 'reg_lambda': 1.9995348138898184, 'n_estimators': 115}. Best is trial 0 with value: 0.7160028555775074.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:24,221] Trial 1 finished with value: 0.6876218323586745 and parameters: {'threshold': '1.5*mean', 'max_features': 1006, 'norm_order': 1, 'learning_rate': 0.17676351715053212, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.6083677945683332, 'colsample_bytree': 0.615847622074301, 'gamma': 6.040195753743694, 'reg_alpha': 6.4682910507980775, 'reg_lambda': 0.9037492807019143, 'n_estimators': 256}. Best is trial 0 with value: 0.7160028555775074.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:24,892] Trial 2 finished with value: 0.7291346646185355 and parameters: {'threshold': 'very_low', 'max_features': 650, 'norm_order': 2, 'learning_rate': 0.2949799263026363, 'max_depth': 24, 'min_child_weight': 4, 'subsample': 0.738709717809245, 'colsample_bytree': 0.8592941039807216, 'gamma': 3.2985339560702287, 'reg_alpha': 5.538540724631281, 'reg_lambda': 6.0840884248471845, 'n_estimators': 104}. Best is trial 2 with value: 0.7291346646185355.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:25,622] Trial 3 finished with value: 0.6547651359998684 and parameters: {'threshold': 'mean', 'max_features': 44, 'norm_order': 1, 'learning_rate': 0.15203063747610884, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.5850993899866203, 'colsample_bytree': 0.7419610548830455, 'gamma': 9.291046597929022, 'reg_alpha': 6.7417072192956065, 'reg_lambda': 8.00695945717935, 'n_estimators': 233}. Best is trial 2 with value: 0.7291346646185355.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:26,228] Trial 4 finished with value: 0.700140931484215 and parameters: {'threshold': 'very_low', 'max_features': 197, 'norm_order': 1, 'learning_rate': 0.13780801866929854, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.9744882819685514, 'colsample_bytree': 0.8110590718449235, 'gamma': 7.252388949961448, 'reg_alpha': 2.320638700209452, 'reg_lambda': 8.188918845741354, 'n_estimators': 93}. Best is trial 2 with value: 0.7291346646185355.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:27,125] Trial 5 finished with value: 0.7598845598845599 and parameters: {'threshold': 'very_low', 'max_features': 769, 'norm_order': 2, 'learning_rate': 0.057121437827271714, 'max_depth': 13, 'min_child_weight': 5, 'subsample': 0.8557277409437319, 'colsample_bytree': 0.5300472383632331, 'gamma': 5.642283303245628, 'reg_alpha': 0.7199907542226935, 'reg_lambda': 8.020313096301807, 'n_estimators': 160}. Best is trial 5 with value: 0.7598845598845599.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:28,034] Trial 6 finished with value: 0.752932472423998 and parameters: {'threshold': 'mean', 'max_features': 188, 'norm_order': 2, 'learning_rate': 0.049909425853960736, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8446444688493939, 'colsample_bytree': 0.7685191742076549, 'gamma': 4.38909333825313, 'reg_alpha': 6.704644126876321, 'reg_lambda': 0.06525053233612632, 'n_estimators': 169}. Best is trial 5 with value: 0.7598845598845599.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:28,735] Trial 7 finished with value: 0.7626862856064894 and parameters: {'threshold': 'median', 'max_features': 70, 'norm_order': 2, 'learning_rate': 0.2263141324759608, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9806912844460409, 'colsample_bytree': 0.6319174298006374, 'gamma': 4.006207963822272, 'reg_alpha': 1.3051378211620446, 'reg_lambda': 8.76915611051725, 'n_estimators': 146}. Best is trial 7 with value: 0.7626862856064894.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:29,602] Trial 8 finished with value: 0.8153846153846155 and parameters: {'threshold': 'mean', 'max_features': 740, 'norm_order': 2, 'learning_rate': 0.15791951051064648, 'max_depth': 29, 'min_child_weight': 3, 'subsample': 0.6404379998238797, 'colsample_bytree': 0.5151109544231391, 'gamma': 1.1029859192719316, 'reg_alpha': 1.765036968347613, 'reg_lambda': 7.730525855860332, 'n_estimators': 137}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:30,234] Trial 9 finished with value: 0.6880261111289077 and parameters: {'threshold': 'very_low', 'max_features': 162, 'norm_order': 1, 'learning_rate': 0.37239324729305107, 'max_depth': 24, 'min_child_weight': 6, 'subsample': 0.5210180146051819, 'colsample_bytree': 0.8772151712274888, 'gamma': 4.573393442953327, 'reg_alpha': 0.7414218689220042, 'reg_lambda': 3.456933915089385, 'n_estimators': 89}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:30,774] Trial 10 finished with value: 0.7712096332785988 and parameters: {'threshold': '0.5*mean', 'max_features': 448, 'norm_order': 2, 'learning_rate': 0.46516625185067395, 'max_depth': 30, 'min_child_weight': 9, 'subsample': 0.7170770555961461, 'colsample_bytree': 0.9492769237998882, 'gamma': 0.12266963308148604, 'reg_alpha': 3.397732423218332, 'reg_lambda': 6.071564648070794, 'n_estimators': 54}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:31,311] Trial 11 finished with value: 0.7425044091710759 and parameters: {'threshold': '0.5*mean', 'max_features': 463, 'norm_order': 2, 'learning_rate': 0.47854352084902774, 'max_depth': 30, 'min_child_weight': 10, 'subsample': 0.6710045417860856, 'colsample_bytree': 0.977640390726892, 'gamma': 0.006035853325495111, 'reg_alpha': 3.363575488644082, 'reg_lambda': 5.673666555472265, 'n_estimators': 50}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:32,233] Trial 12 finished with value: 0.7339782785930584 and parameters: {'threshold': '0.5*mean', 'max_features': 436, 'norm_order': 2, 'learning_rate': 0.4896985268753752, 'max_depth': 30, 'min_child_weight': 10, 'subsample': 0.7305228191563051, 'colsample_bytree': 0.9707072569912477, 'gamma': 0.034875357455331366, 'reg_alpha': 3.6048725895432376, 'reg_lambda': 6.484686449339703, 'n_estimators': 207}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:32,762] Trial 13 finished with value: 0.7617325800376648 and parameters: {'threshold': '0.5*mean', 'max_features': 913, 'norm_order': 2, 'learning_rate': 0.3506667747123171, 'max_depth': 18, 'min_child_weight': 7, 'subsample': 0.6675290601812819, 'colsample_bytree': 0.5679472033149083, 'gamma': 1.7193384646021443, 'reg_alpha': 4.093053296497113, 'reg_lambda': 3.886821042734006, 'n_estimators': 61}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:33,628] Trial 14 finished with value: 0.7510928493979341 and parameters: {'threshold': 'median', 'max_features': 378, 'norm_order': 2, 'learning_rate': 0.388683802082531, 'max_depth': 27, 'min_child_weight': 8, 'subsample': 0.7871924002280607, 'colsample_bytree': 0.6622408247249414, 'gamma': 1.4958546930407626, 'reg_alpha': 2.379341062651185, 'reg_lambda': 9.987718646605733, 'n_estimators': 287}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:34,371] Trial 15 finished with value: 0.7551848112923508 and parameters: {'threshold': '1.5*mean', 'max_features': 591, 'norm_order': 2, 'learning_rate': 0.29392819170771883, 'max_depth': 19, 'min_child_weight': 8, 'subsample': 0.6675417030036954, 'colsample_bytree': 0.9024646926448494, 'gamma': 1.3006021971829245, 'reg_alpha': 2.42385232307174, 'reg_lambda': 4.364460374020342, 'n_estimators': 202}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:35,179] Trial 16 finished with value: 0.7377823291801787 and parameters: {'threshold': '0.5*mean', 'max_features': 820, 'norm_order': 2, 'learning_rate': 0.09641901508329898, 'max_depth': 27, 'min_child_weight': 3, 'subsample': 0.5095310636167674, 'colsample_bytree': 0.5080093552711176, 'gamma': 2.73666179589892, 'reg_alpha': 4.819471821110122, 'reg_lambda': 7.029779410290837, 'n_estimators': 133}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:35,695] Trial 17 finished with value: 0.7037367929838062 and parameters: {'threshold': 'mean', 'max_features': 330, 'norm_order': 1, 'learning_rate': 0.453776794136284, 'max_depth': 27, 'min_child_weight': 9, 'subsample': 0.6073693735374681, 'colsample_bytree': 0.6835475435783129, 'gamma': 0.6537784113070371, 'reg_alpha': 9.635615500852222, 'reg_lambda': 4.880200685904899, 'n_estimators': 73}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:36,549] Trial 18 finished with value: 0.7245033717617098 and parameters: {'threshold': '0.5*mean', 'max_features': 602, 'norm_order': 2, 'learning_rate': 0.014963595668835095, 'max_depth': 21, 'min_child_weight': 6, 'subsample': 0.7847127821411848, 'colsample_bytree': 0.9311988313554316, 'gamma': 7.9436828170242855, 'reg_alpha': 0.16123329962325617, 'reg_lambda': 9.53421696660978, 'n_estimators': 126}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:37,279] Trial 19 finished with value: 0.8073593073593074 and parameters: {'threshold': 'mean', 'max_features': 320, 'norm_order': 2, 'learning_rate': 0.41111892186921584, 'max_depth': 15, 'min_child_weight': 3, 'subsample': 0.7078794431429459, 'colsample_bytree': 0.8107197516158199, 'gamma': 2.312430262838822, 'reg_alpha': 1.8676922254904804, 'reg_lambda': 7.090267962534439, 'n_estimators': 195}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:38,121] Trial 20 finished with value: 0.7581645685093962 and parameters: {'threshold': 'mean', 'max_features': 279, 'norm_order': 1, 'learning_rate': 0.29367075679388177, 'max_depth': 15, 'min_child_weight': 3, 'subsample': 0.5609041210596728, 'colsample_bytree': 0.7949714283281601, 'gamma': 3.1409430290777913, 'reg_alpha': 2.0331667387254337, 'reg_lambda': 7.263165464832814, 'n_estimators': 197}. Best is trial 8 with value: 0.8153846153846155.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:38,896] Trial 21 finished with value: 0.8237464345106331 and parameters: {'threshold': 'mean', 'max_features': 533, 'norm_order': 2, 'learning_rate': 0.43877117389709464, 'max_depth': 15, 'min_child_weight': 4, 'subsample': 0.700085153296808, 'colsample_bytree': 0.8340323956716891, 'gamma': 1.1217509649883153, 'reg_alpha': 3.2075451908533434, 'reg_lambda': 5.842802006742377, 'n_estimators': 183}. Best is trial 21 with value: 0.8237464345106331.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:39,784] Trial 22 finished with value: 0.8347702894150982 and parameters: {'threshold': 'mean', 'max_features': 529, 'norm_order': 2, 'learning_rate': 0.4203554575677758, 'max_depth': 15, 'min_child_weight': 3, 'subsample': 0.6829116873550835, 'colsample_bytree': 0.8384454833282787, 'gamma': 2.0069480987212485, 'reg_alpha': 1.5979246026797886, 'reg_lambda': 7.242970176396888, 'n_estimators': 182}. Best is trial 22 with value: 0.8347702894150982.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:40,692] Trial 23 finished with value: 0.7927913789495711 and parameters: {'threshold': 'mean', 'max_features': 532, 'norm_order': 2, 'learning_rate': 0.4258142415255338, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.6357402917955132, 'colsample_bytree': 0.8253681423372992, 'gamma': 1.0963588200345962, 'reg_alpha': 2.921671597417568, 'reg_lambda': 5.200922295340613, 'n_estimators': 230}. Best is trial 22 with value: 0.8347702894150982.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:41,297] Trial 24 finished with value: 0.870136153155021 and parameters: {'threshold': 'mean', 'max_features': 673, 'norm_order': 2, 'learning_rate': 0.32655144488339827, 'max_depth': 16, 'min_child_weight': 2, 'subsample': 0.7813970234664616, 'colsample_bytree': 0.8439530930962909, 'gamma': 1.8140487196741757, 'reg_alpha': 1.4454902824741067, 'reg_lambda': 2.937705456298252, 'n_estimators': 153}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:42,090] Trial 25 finished with value: 0.7864406779661017 and parameters: {'threshold': 'mean', 'max_features': 661, 'norm_order': 2, 'learning_rate': 0.3400832799418645, 'max_depth': 16, 'min_child_weight': 2, 'subsample': 0.7881774233041712, 'colsample_bytree': 0.8530641847295669, 'gamma': 3.81885746291319, 'reg_alpha': 4.368241624930528, 'reg_lambda': 3.319035032933918, 'n_estimators': 181}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:42,958] Trial 26 finished with value: 0.8553459119496857 and parameters: {'threshold': 'mean', 'max_features': 529, 'norm_order': 2, 'learning_rate': 0.42335112140029185, 'max_depth': 19, 'min_child_weight': 1, 'subsample': 0.8272869612917613, 'colsample_bytree': 0.9013010916660867, 'gamma': 2.043014713943491, 'reg_alpha': 0.10374845200472027, 'reg_lambda': 2.98761278488246, 'n_estimators': 155}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:43,713] Trial 27 finished with value: 0.8568368967172556 and parameters: {'threshold': 'mean', 'max_features': 872, 'norm_order': 2, 'learning_rate': 0.330496380658818, 'max_depth': 18, 'min_child_weight': 1, 'subsample': 0.9079758924543022, 'colsample_bytree': 0.9107190469467766, 'gamma': 1.9895582156202032, 'reg_alpha': 0.060658600681117836, 'reg_lambda': 2.681504473921134, 'n_estimators': 166}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:44,401] Trial 28 finished with value: 0.790378724589251 and parameters: {'threshold': 'median', 'max_features': 881, 'norm_order': 2, 'learning_rate': 0.3206815601449316, 'max_depth': 19, 'min_child_weight': 1, 'subsample': 0.9123398794037352, 'colsample_bytree': 0.9112553815231039, 'gamma': 5.30227043033729, 'reg_alpha': 0.7622715579342629, 'reg_lambda': 2.7077317164037242, 'n_estimators': 154}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:45,064] Trial 29 finished with value: 0.843627636731085 and parameters: {'threshold': '1.5*mean', 'max_features': 952, 'norm_order': 2, 'learning_rate': 0.21922502283196998, 'max_depth': 21, 'min_child_weight': 1, 'subsample': 0.9176533736524969, 'colsample_bytree': 0.891456240895546, 'gamma': 2.605710426921052, 'reg_alpha': 0.38512185401256516, 'reg_lambda': 1.6560945878493007, 'n_estimators': 119}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:45,794] Trial 30 finished with value: 0.8387878787878789 and parameters: {'threshold': 'mean', 'max_features': 833, 'norm_order': 2, 'learning_rate': 0.2546197179703345, 'max_depth': 18, 'min_child_weight': 2, 'subsample': 0.8640635593957893, 'colsample_bytree': 0.995390678166878, 'gamma': 3.1326827175126275, 'reg_alpha': 0.020619291110269708, 'reg_lambda': 2.2340131525125493, 'n_estimators': 163}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:46,268] Trial 31 finished with value: 0.7316528585698338 and parameters: {'threshold': '1.5*mean', 'max_features': 1028, 'norm_order': 2, 'learning_rate': 0.21466923857085835, 'max_depth': 21, 'min_child_weight': 1, 'subsample': 0.9234111776978637, 'colsample_bytree': 0.8880695242791865, 'gamma': 2.420325755845296, 'reg_alpha': 8.739920936993498, 'reg_lambda': 1.6091678465414865, 'n_estimators': 120}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:46,924] Trial 32 finished with value: 0.8495919285392969 and parameters: {'threshold': '1.5*mean', 'max_features': 930, 'norm_order': 2, 'learning_rate': 0.2592376675958614, 'max_depth': 23, 'min_child_weight': 1, 'subsample': 0.8165323170309655, 'colsample_bytree': 0.9322124672076837, 'gamma': 2.0353017618564095, 'reg_alpha': 1.0984907223831326, 'reg_lambda': 1.3961776796826797, 'n_estimators': 112}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:47,453] Trial 33 finished with value: 0.8334950366590951 and parameters: {'threshold': '1.5*mean', 'max_features': 669, 'norm_order': 2, 'learning_rate': 0.26670205856527607, 'max_depth': 23, 'min_child_weight': 2, 'subsample': 0.8217423291941022, 'colsample_bytree': 0.9477945867970213, 'gamma': 3.5971220101292434, 'reg_alpha': 1.452432905795971, 'reg_lambda': 0.6003437339291005, 'n_estimators': 106}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:48,221] Trial 34 finished with value: 0.8199233716475095 and parameters: {'threshold': '1.5*mean', 'max_features': 972, 'norm_order': 2, 'learning_rate': 0.3269557032518039, 'max_depth': 17, 'min_child_weight': 1, 'subsample': 0.7607356943679005, 'colsample_bytree': 0.9247836633753415, 'gamma': 1.9140208681657038, 'reg_alpha': 1.0339875150465778, 'reg_lambda': 2.733404261819802, 'n_estimators': 142}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:48,669] Trial 35 finished with value: 0.6597488746742478 and parameters: {'threshold': 'mean', 'max_features': 801, 'norm_order': 1, 'learning_rate': 0.37470556590270077, 'max_depth': 25, 'min_child_weight': 1, 'subsample': 0.8230443979992927, 'colsample_bytree': 0.7400045271698827, 'gamma': 6.301322836050137, 'reg_alpha': 8.409125342165328, 'reg_lambda': 1.1581615907634424, 'n_estimators': 223}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:49,233] Trial 36 finished with value: 0.7045677361853833 and parameters: {'threshold': '1.5*mean', 'max_features': 693, 'norm_order': 2, 'learning_rate': 0.312521324315618, 'max_depth': 20, 'min_child_weight': 2, 'subsample': 0.889780320993381, 'colsample_bytree': 0.9472291586803783, 'gamma': 9.61244293400732, 'reg_alpha': 5.833484659584356, 'reg_lambda': 2.4746059306172086, 'n_estimators': 155}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:49,887] Trial 37 finished with value: 0.8486722427898897 and parameters: {'threshold': 'mean', 'max_features': 907, 'norm_order': 2, 'learning_rate': 0.2588764423570423, 'max_depth': 23, 'min_child_weight': 1, 'subsample': 0.947749645159832, 'colsample_bytree': 0.8542046460737472, 'gamma': 0.7049531305049459, 'reg_alpha': 0.11319367988138479, 'reg_lambda': 3.4640624880300814, 'n_estimators': 95}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:50,648] Trial 38 finished with value: 0.8331829907104086 and parameters: {'threshold': 'very_low', 'max_features': 852, 'norm_order': 2, 'learning_rate': 0.1923710051508156, 'max_depth': 13, 'min_child_weight': 2, 'subsample': 0.8252545795444922, 'colsample_bytree': 0.782795133145021, 'gamma': 2.972662037316057, 'reg_alpha': 1.1322791428613672, 'reg_lambda': 1.8749463923569356, 'n_estimators': 108}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:51,502] Trial 39 finished with value: 0.8486029889538661 and parameters: {'threshold': 'mean', 'max_features': 747, 'norm_order': 1, 'learning_rate': 0.3552470655511088, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7601921361376128, 'colsample_bytree': 0.8700588768418112, 'gamma': 4.592367189327075, 'reg_alpha': 0.671499015485817, 'reg_lambda': 1.0824423614579768, 'n_estimators': 173}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:52,083] Trial 40 finished with value: 0.7729794571899835 and parameters: {'threshold': 'median', 'max_features': 1044, 'norm_order': 2, 'learning_rate': 0.39929831309575015, 'max_depth': 25, 'min_child_weight': 2, 'subsample': 0.8779575599423729, 'colsample_bytree': 0.9149611819937703, 'gamma': 2.176880284983042, 'reg_alpha': 2.4842763622295907, 'reg_lambda': 0.2254553657301992, 'n_estimators': 256}. Best is trial 24 with value: 0.870136153155021.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:52,745] Trial 41 finished with value: 0.8823651721897336 and parameters: {'threshold': 'mean', 'max_features': 913, 'norm_order': 2, 'learning_rate': 0.25010566628822967, 'max_depth': 23, 'min_child_weight': 1, 'subsample': 0.997428754300239, 'colsample_bytree': 0.8762155110465438, 'gamma': 0.5600267431128495, 'reg_alpha': 0.001378047424141715, 'reg_lambda': 3.1216875834803712, 'n_estimators': 75}. Best is trial 41 with value: 0.8823651721897336.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:53,498] Trial 42 finished with value: 0.8595405179615705 and parameters: {'threshold': 'mean', 'max_features': 971, 'norm_order': 2, 'learning_rate': 0.28034956338803435, 'max_depth': 23, 'min_child_weight': 1, 'subsample': 0.9974350965170871, 'colsample_bytree': 0.8802171017219514, 'gamma': 0.9225306080011204, 'reg_alpha': 0.5808667587936295, 'reg_lambda': 3.067527273462463, 'n_estimators': 133}. Best is trial 41 with value: 0.8823651721897336.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:54,100] Trial 43 finished with value: 0.8713558788746759 and parameters: {'threshold': 'mean', 'max_features': 600, 'norm_order': 2, 'learning_rate': 0.2827505744091497, 'max_depth': 17, 'min_child_weight': 1, 'subsample': 0.9955684835129991, 'colsample_bytree': 0.8703806856286053, 'gamma': 0.5509045932522493, 'reg_alpha': 0.5206728131840103, 'reg_lambda': 3.084811252724736, 'n_estimators': 80}. Best is trial 41 with value: 0.8823651721897336.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:54,772] Trial 44 finished with value: 0.8659934318555008 and parameters: {'threshold': 'mean', 'max_features': 975, 'norm_order': 2, 'learning_rate': 0.2820577357343066, 'max_depth': 13, 'min_child_weight': 2, 'subsample': 0.9960754945975479, 'colsample_bytree': 0.8694284788812678, 'gamma': 0.46581195762083616, 'reg_alpha': 0.5705623335000513, 'reg_lambda': 4.097128242281936, 'n_estimators': 68}. Best is trial 41 with value: 0.8823651721897336.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:55,402] Trial 45 finished with value: 0.8616092901807187 and parameters: {'threshold': 'mean', 'max_features': 1005, 'norm_order': 2, 'learning_rate': 0.285058743482466, 'max_depth': 11, 'min_child_weight': 2, 'subsample': 0.9997135397065168, 'colsample_bytree': 0.7549053079610399, 'gamma': 0.371439757983306, 'reg_alpha': 0.7726876780844458, 'reg_lambda': 3.9872986861957793, 'n_estimators': 74}. Best is trial 41 with value: 0.8823651721897336.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:56,059] Trial 46 finished with value: 0.8403263403263402 and parameters: {'threshold': 'mean', 'max_features': 987, 'norm_order': 2, 'learning_rate': 0.23139687611546317, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.9592526848676433, 'colsample_bytree': 0.7525980499319264, 'gamma': 0.5602823190450389, 'reg_alpha': 1.3979501964444219, 'reg_lambda': 3.9902277272948563, 'n_estimators': 79}. Best is trial 41 with value: 0.8823651721897336.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:56,800] Trial 47 finished with value: 0.8833563507009835 and parameters: {'threshold': 'mean', 'max_features': 770, 'norm_order': 2, 'learning_rate': 0.18213868052356996, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.9982747817352581, 'colsample_bytree': 0.735450666210041, 'gamma': 0.3651647490348566, 'reg_alpha': 0.9320806030346587, 'reg_lambda': 4.560198313474037, 'n_estimators': 79}. Best is trial 47 with value: 0.8833563507009835.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:57,471] Trial 48 finished with value: 0.8355815464587394 and parameters: {'threshold': 'very_low', 'max_features': 774, 'norm_order': 2, 'learning_rate': 0.15524478963073104, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9465123366056288, 'colsample_bytree': 0.6871617252607651, 'gamma': 0.2781161195276588, 'reg_alpha': 2.846912490851704, 'reg_lambda': 4.502367253479451, 'n_estimators': 61}. Best is trial 47 with value: 0.8833563507009835.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:58,203] Trial 49 finished with value: 0.8343777465785479 and parameters: {'threshold': 'mean', 'max_features': 599, 'norm_order': 2, 'learning_rate': 0.12712881358760603, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9718324047333642, 'colsample_bytree': 0.7922047209363318, 'gamma': 1.5957122405565745, 'reg_alpha': 1.9761035718828306, 'reg_lambda': 5.3128608177269, 'n_estimators': 85}. Best is trial 47 with value: 0.8833563507009835.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:59,007] Trial 50 finished with value: 0.8656253461836713 and parameters: {'threshold': 'mean', 'max_features': 704, 'norm_order': 2, 'learning_rate': 0.17198839028921337, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.9361272324311412, 'colsample_bytree': 0.7139091739408414, 'gamma': 1.4275826777382035, 'reg_alpha': 1.0910061130511788, 'reg_lambda': 4.336589032476303, 'n_estimators': 96}. Best is trial 47 with value: 0.8833563507009835.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:27:59,805] Trial 51 finished with value: 0.879477017667321 and parameters: {'threshold': 'mean', 'max_features': 697, 'norm_order': 2, 'learning_rate': 0.2000912586908953, 'max_depth': 6, 'min_child_weight': 2, 'subsample': 0.979018322196645, 'colsample_bytree': 0.7212831390641439, 'gamma': 0.7851960886131915, 'reg_alpha': 1.2320753566894573, 'reg_lambda': 4.624366874807669, 'n_estimators': 95}. Best is trial 47 with value: 0.8833563507009835.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:00,455] Trial 52 finished with value: 0.8778115159694106 and parameters: {'threshold': 'mean', 'max_features': 635, 'norm_order': 2, 'learning_rate': 0.20008742386148026, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9843359139510265, 'colsample_bytree': 0.7317035853346723, 'gamma': 0.03491798031556753, 'reg_alpha': 0.5140173294825462, 'reg_lambda': 3.598212257948923, 'n_estimators': 65}. Best is trial 47 with value: 0.8833563507009835.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:01,167] Trial 53 finished with value: 0.8952309472433311 and parameters: {'threshold': 'mean', 'max_features': 620, 'norm_order': 2, 'learning_rate': 0.12243759368947355, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9736427801856483, 'colsample_bytree': 0.7318346177479617, 'gamma': 0.02524869265873242, 'reg_alpha': 1.7924682768446585, 'reg_lambda': 4.723542094454843, 'n_estimators': 61}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:01,724] Trial 54 finished with value: 0.84347442680776 and parameters: {'threshold': 'mean', 'max_features': 626, 'norm_order': 2, 'learning_rate': 0.18990648522856926, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.974664006597273, 'colsample_bytree': 0.6191339641933316, 'gamma': 0.77265087493317, 'reg_alpha': 2.0911413162124872, 'reg_lambda': 4.766659598976739, 'n_estimators': 58}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:02,676] Trial 55 finished with value: 0.8817823425666563 and parameters: {'threshold': 'mean', 'max_features': 731, 'norm_order': 2, 'learning_rate': 0.10012688006822956, 'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.9629092769201111, 'colsample_bytree': 0.7231831304232476, 'gamma': 0.0010964000198175061, 'reg_alpha': 1.6974513737381691, 'reg_lambda': 3.6572178630290613, 'n_estimators': 84}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:03,445] Trial 56 finished with value: 0.8606151152236601 and parameters: {'threshold': 'mean', 'max_features': 742, 'norm_order': 2, 'learning_rate': 0.12468644928046554, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.9626810252470689, 'colsample_bytree': 0.7148492870599159, 'gamma': 0.0939638660851875, 'reg_alpha': 3.8144595171478173, 'reg_lambda': 5.415095422006548, 'n_estimators': 68}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:04,090] Trial 57 finished with value: 0.8308156873323442 and parameters: {'threshold': 'very_low', 'max_features': 784, 'norm_order': 2, 'learning_rate': 0.0931797677893691, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9405910511212294, 'colsample_bytree': 0.6586741506155106, 'gamma': 0.04659491208682205, 'reg_alpha': 2.7503037665814327, 'reg_lambda': 3.762725276238441, 'n_estimators': 50}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:04,668] Trial 58 finished with value: 0.6528442728442729 and parameters: {'threshold': 'median', 'max_features': 484, 'norm_order': 2, 'learning_rate': 0.10845751803412154, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.9787923607085361, 'colsample_bytree': 0.7223841479347118, 'gamma': 8.714857334891127, 'reg_alpha': 7.270055352562229, 'reg_lambda': 4.805831645479675, 'n_estimators': 99}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:05,619] Trial 59 finished with value: 0.8453541260558803 and parameters: {'threshold': 'mean', 'max_features': 570, 'norm_order': 2, 'learning_rate': 0.06279141242563752, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9555423515712659, 'colsample_bytree': 0.6812226047436588, 'gamma': 1.0956125473195304, 'reg_alpha': 2.163370315701216, 'reg_lambda': 6.578641579293291, 'n_estimators': 86}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:06,475] Trial 60 finished with value: 0.876275656461415 and parameters: {'threshold': '0.5*mean', 'max_features': 721, 'norm_order': 1, 'learning_rate': 0.17513670957594296, 'max_depth': 9, 'min_child_weight': 3, 'subsample': 0.9272870304501928, 'colsample_bytree': 0.7708900982838085, 'gamma': 1.3051470313898854, 'reg_alpha': 1.5763399156942555, 'reg_lambda': 3.6438012060934044, 'n_estimators': 67}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:07,143] Trial 61 finished with value: 0.8521910188576856 and parameters: {'threshold': '0.5*mean', 'max_features': 636, 'norm_order': 1, 'learning_rate': 0.17233843151512007, 'max_depth': 9, 'min_child_weight': 3, 'subsample': 0.9306844662642243, 'colsample_bytree': 0.7697855141428867, 'gamma': 1.341279015158813, 'reg_alpha': 1.7412766739552565, 'reg_lambda': 3.5449791240013093, 'n_estimators': 68}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:07,918] Trial 62 finished with value: 0.8664322740590489 and parameters: {'threshold': '0.5*mean', 'max_features': 741, 'norm_order': 1, 'learning_rate': 0.19551957970193215, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.98186569354906, 'colsample_bytree': 0.7374707177361929, 'gamma': 0.3601205090674912, 'reg_alpha': 1.6874769341914218, 'reg_lambda': 4.341404890132301, 'n_estimators': 89}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:08,515] Trial 63 finished with value: 0.874235190097259 and parameters: {'threshold': '0.5*mean', 'max_features': 566, 'norm_order': 1, 'learning_rate': 0.2389655649854749, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9004258713494607, 'colsample_bytree': 0.7041483077811185, 'gamma': 0.9043253720801605, 'reg_alpha': 0.9178183050029399, 'reg_lambda': 3.7260055770791087, 'n_estimators': 62}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:09,395] Trial 64 finished with value: 0.8640957807624474 and parameters: {'threshold': '0.5*mean', 'max_features': 710, 'norm_order': 1, 'learning_rate': 0.13990711378706727, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.9666809863873272, 'colsample_bytree': 0.6468194114981883, 'gamma': 0.05388524291568549, 'reg_alpha': 1.3393514320274842, 'reg_lambda': 5.0401934250671125, 'n_estimators': 77}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:10,059] Trial 65 finished with value: 0.8355533556985462 and parameters: {'threshold': 'mean', 'max_features': 816, 'norm_order': 1, 'learning_rate': 0.07010123220173442, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9784827810133758, 'colsample_bytree': 0.6981240051559977, 'gamma': 0.8026967635716971, 'reg_alpha': 0.36397211505142235, 'reg_lambda': 5.624023275321118, 'n_estimators': 55}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:10,673] Trial 66 finished with value: 0.8328834907782277 and parameters: {'threshold': 'mean', 'max_features': 644, 'norm_order': 2, 'learning_rate': 0.20860793987284715, 'max_depth': 9, 'min_child_weight': 3, 'subsample': 0.9277931945437213, 'colsample_bytree': 0.591632601056757, 'gamma': 1.2081361392167365, 'reg_alpha': 2.478098060021279, 'reg_lambda': 4.484343763947342, 'n_estimators': 66}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:11,513] Trial 67 finished with value: 0.8675642385388448 and parameters: {'threshold': '0.5*mean', 'max_features': 710, 'norm_order': 2, 'learning_rate': 0.1484247287429709, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9532089621851768, 'colsample_bytree': 0.7646533734472473, 'gamma': 0.3539631205392002, 'reg_alpha': 1.8594831329345305, 'reg_lambda': 3.292150322696398, 'n_estimators': 101}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:12,517] Trial 68 finished with value: 0.8178495349237221 and parameters: {'threshold': 'mean', 'max_features': 768, 'norm_order': 2, 'learning_rate': 0.028613387906267704, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.9808341986368048, 'colsample_bytree': 0.8120464237682837, 'gamma': 1.4782973953967498, 'reg_alpha': 0.9800732144174471, 'reg_lambda': 6.157448549429967, 'n_estimators': 85}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:13,531] Trial 69 finished with value: 0.8588743939621133 and parameters: {'threshold': 'mean', 'max_features': 485, 'norm_order': 2, 'learning_rate': 0.10750865047749504, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.894763233963036, 'colsample_bytree': 0.7305544265168126, 'gamma': 0.005999110845976707, 'reg_alpha': 3.063102374567432, 'reg_lambda': 2.1823145109459503, 'n_estimators': 74}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:14,210] Trial 70 finished with value: 0.840716094194618 and parameters: {'threshold': 'mean', 'max_features': 669, 'norm_order': 2, 'learning_rate': 0.16391430607415025, 'max_depth': 10, 'min_child_weight': 2, 'subsample': 0.9872201357207006, 'colsample_bytree': 0.6785289053723098, 'gamma': 1.0658891476158712, 'reg_alpha': 1.509199869841741, 'reg_lambda': 4.873749358713633, 'n_estimators': 51}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:15,004] Trial 71 finished with value: 0.859047619047619 and parameters: {'threshold': '0.5*mean', 'max_features': 423, 'norm_order': 1, 'learning_rate': 0.22790179459493146, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.962612405401203, 'colsample_bytree': 0.698657971317116, 'gamma': 0.74738547859071, 'reg_alpha': 0.3201555372255206, 'reg_lambda': 3.7553149781874104, 'n_estimators': 61}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:15,731] Trial 72 finished with value: 0.8875685234305924 and parameters: {'threshold': '0.5*mean', 'max_features': 557, 'norm_order': 1, 'learning_rate': 0.2400894988382086, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.892458208337165, 'colsample_bytree': 0.7008354335932362, 'gamma': 0.9129773547634031, 'reg_alpha': 0.9548348157533597, 'reg_lambda': 4.104522654764136, 'n_estimators': 62}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:16,532] Trial 73 finished with value: 0.8536194351954619 and parameters: {'threshold': '0.5*mean', 'max_features': 560, 'norm_order': 1, 'learning_rate': 0.24252217765393516, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.9197177873043262, 'colsample_bytree': 0.774316079184184, 'gamma': 0.4394184449335563, 'reg_alpha': 1.2990334234646048, 'reg_lambda': 4.164320765545056, 'n_estimators': 91}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:17,211] Trial 74 finished with value: 0.8415750915750916 and parameters: {'threshold': '0.5*mean', 'max_features': 622, 'norm_order': 1, 'learning_rate': 0.20458337220381262, 'max_depth': 6, 'min_child_weight': 2, 'subsample': 0.9400898006946916, 'colsample_bytree': 0.7280466975189661, 'gamma': 1.724269888737465, 'reg_alpha': 0.9522120064812182, 'reg_lambda': 4.584187456118271, 'n_estimators': 80}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:17,850] Trial 75 finished with value: 0.8174222004410684 and parameters: {'threshold': '0.5*mean', 'max_features': 861, 'norm_order': 1, 'learning_rate': 0.18134829108115158, 'max_depth': 8, 'min_child_weight': 3, 'subsample': 0.855279717566279, 'colsample_bytree': 0.6634600505475271, 'gamma': 0.5849436832811468, 'reg_alpha': 5.206493708768623, 'reg_lambda': 3.3273099904933243, 'n_estimators': 71}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:18,622] Trial 76 finished with value: 0.8558683321060964 and parameters: {'threshold': 'median', 'max_features': 96, 'norm_order': 1, 'learning_rate': 0.12831475723169086, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8769033959644418, 'colsample_bytree': 0.7526374483695214, 'gamma': 1.0788391906615764, 'reg_alpha': 0.4075657440976861, 'reg_lambda': 3.6734097047566587, 'n_estimators': 56}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:19,485] Trial 77 finished with value: 0.7468932748538011 and parameters: {'threshold': 'mean', 'max_features': 688, 'norm_order': 2, 'learning_rate': 0.07930013676336509, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9097225932457913, 'colsample_bytree': 0.7089655194472829, 'gamma': 6.540911046145463, 'reg_alpha': 1.6287045886840499, 'reg_lambda': 5.148262784617929, 'n_estimators': 93}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:20,462] Trial 78 finished with value: 0.8788953247081327 and parameters: {'threshold': 'very_low', 'max_features': 509, 'norm_order': 1, 'learning_rate': 0.24913114191615499, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.9888241637844708, 'colsample_bytree': 0.8008454323406798, 'gamma': 0.206821524823331, 'reg_alpha': 1.2312502979922373, 'reg_lambda': 4.179862910731448, 'n_estimators': 81}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:21,594] Trial 79 finished with value: 0.850909090909091 and parameters: {'threshold': 'very_low', 'max_features': 405, 'norm_order': 2, 'learning_rate': 0.24099403115545645, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.987976883430116, 'colsample_bytree': 0.8152450943186782, 'gamma': 0.25232152001030095, 'reg_alpha': 0.004908105511447743, 'reg_lambda': 4.181429033746776, 'n_estimators': 112}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:22,396] Trial 80 finished with value: 0.807577692635164 and parameters: {'threshold': 'very_low', 'max_features': 573, 'norm_order': 2, 'learning_rate': 0.2677752223898156, 'max_depth': 28, 'min_child_weight': 7, 'subsample': 0.968619586632853, 'colsample_bytree': 0.7962020968453184, 'gamma': 0.8591864116849333, 'reg_alpha': 0.7518793286167708, 'reg_lambda': 3.165343143142694, 'n_estimators': 102}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:23,258] Trial 81 finished with value: 0.8446235826339805 and parameters: {'threshold': 'very_low', 'max_features': 511, 'norm_order': 1, 'learning_rate': 0.2080221309430939, 'max_depth': 9, 'min_child_weight': 3, 'subsample': 0.9577048216005226, 'colsample_bytree': 0.7432256078958428, 'gamma': 0.3021098425229382, 'reg_alpha': 1.208902173516692, 'reg_lambda': 4.606921075820987, 'n_estimators': 81}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:24,060] Trial 82 finished with value: 0.8410323140316635 and parameters: {'threshold': 'very_low', 'max_features': 652, 'norm_order': 1, 'learning_rate': 0.2228704124139445, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.943494799953142, 'colsample_bytree': 0.72798217355724, 'gamma': 0.5293205494878792, 'reg_alpha': 2.642195705970736, 'reg_lambda': 2.8438134245619633, 'n_estimators': 65}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:24,628] Trial 83 finished with value: 0.8696594427244583 and parameters: {'threshold': 'mean', 'max_features': 618, 'norm_order': 1, 'learning_rate': 0.30392083434843314, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.998851516989776, 'colsample_bytree': 0.7824674669950684, 'gamma': 1.3854823425813745, 'reg_alpha': 2.1977334737038996, 'reg_lambda': 2.4983786036720437, 'n_estimators': 73}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:25,347] Trial 84 finished with value: 0.8785566858322277 and parameters: {'threshold': 'mean', 'max_features': 730, 'norm_order': 1, 'learning_rate': 0.18071867666157926, 'max_depth': 8, 'min_child_weight': 3, 'subsample': 0.9828712574764522, 'colsample_bytree': 0.7409536444467765, 'gamma': 0.6330463582047945, 'reg_alpha': 0.8261289991669059, 'reg_lambda': 3.9700269888600435, 'n_estimators': 57}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:26,020] Trial 85 finished with value: 0.8639858906525574 and parameters: {'threshold': 'mean', 'max_features': 840, 'norm_order': 1, 'learning_rate': 0.25566376115005524, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.9862142659597395, 'colsample_bytree': 0.6879161369972786, 'gamma': 0.6594914729323327, 'reg_alpha': 0.30073988725670225, 'reg_lambda': 3.9356997114635157, 'n_estimators': 59}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:26,857] Trial 86 finished with value: 0.8336385836385837 and parameters: {'threshold': 'mean', 'max_features': 508, 'norm_order': 1, 'learning_rate': 0.1945621151848767, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.9701795568041257, 'colsample_bytree': 0.7432905285167413, 'gamma': 0.1969139911713088, 'reg_alpha': 0.798434662610732, 'reg_lambda': 4.25697174568959, 'n_estimators': 84}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:28,175] Trial 87 finished with value: 0.8685714285714287 and parameters: {'threshold': 'mean', 'max_features': 792, 'norm_order': 2, 'learning_rate': 0.14199717693039926, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9874514135386889, 'colsample_bytree': 0.7183793800392486, 'gamma': 0.9443609100605166, 'reg_alpha': 0.6318541129595232, 'reg_lambda': 5.454475858477023, 'n_estimators': 287}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:28,922] Trial 88 finished with value: 0.8079272254710851 and parameters: {'threshold': 'mean', 'max_features': 894, 'norm_order': 2, 'learning_rate': 0.15973537757170767, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.951137701036595, 'colsample_bytree': 0.7581457207782918, 'gamma': 1.6870760694914777, 'reg_alpha': 1.2158429992401554, 'reg_lambda': 5.873036899389825, 'n_estimators': 50}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:29,710] Trial 89 finished with value: 0.8737530099759202 and parameters: {'threshold': 'mean', 'max_features': 547, 'norm_order': 2, 'learning_rate': 0.18742692699539548, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.9715048601743165, 'colsample_bytree': 0.6709186349312699, 'gamma': 0.6143008212114662, 'reg_alpha': 0.26956955641242036, 'reg_lambda': 4.650460868070951, 'n_estimators': 74}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:30,575] Trial 90 finished with value: 0.8116626311541566 and parameters: {'threshold': 'mean', 'max_features': 679, 'norm_order': 1, 'learning_rate': 0.2152541816342451, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.9984139847802265, 'colsample_bytree': 0.7981557492085343, 'gamma': 0.21808460565255683, 'reg_alpha': 1.8980896016961741, 'reg_lambda': 5.030795977467924, 'n_estimators': 120}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:31,288] Trial 91 finished with value: 0.8287535055651758 and parameters: {'threshold': 'very_low', 'max_features': 716, 'norm_order': 1, 'learning_rate': 0.20223075111088787, 'max_depth': 10, 'min_child_weight': 3, 'subsample': 0.9231213119019811, 'colsample_bytree': 0.7818183690045982, 'gamma': 1.2357373569271737, 'reg_alpha': 1.5905856006764871, 'reg_lambda': 3.476786646208643, 'n_estimators': 64}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:32,235] Trial 92 finished with value: 0.8801428548910462 and parameters: {'threshold': '0.5*mean', 'max_features': 731, 'norm_order': 1, 'learning_rate': 0.1664082819303198, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9387929767904903, 'colsample_bytree': 0.7345456242781505, 'gamma': 0.04918860062889341, 'reg_alpha': 1.0293704920709024, 'reg_lambda': 3.92455175366313, 'n_estimators': 90}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:33,143] Trial 93 finished with value: 0.8745679012345678 and parameters: {'threshold': 'mean', 'max_features': 773, 'norm_order': 1, 'learning_rate': 0.16534567029452996, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9534417974090872, 'colsample_bytree': 0.7331250395574032, 'gamma': 0.04764574739658067, 'reg_alpha': 0.5411616209053551, 'reg_lambda': 3.981991117335546, 'n_estimators': 90}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:33,901] Trial 94 finished with value: 0.8603890362511052 and parameters: {'threshold': 'mean', 'max_features': 819, 'norm_order': 1, 'learning_rate': 0.232548459004259, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9383069959467736, 'colsample_bytree': 0.7046542956137806, 'gamma': 0.40810440315077723, 'reg_alpha': 1.0497760937615666, 'reg_lambda': 4.398446953039579, 'n_estimators': 108}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:34,732] Trial 95 finished with value: 0.8504273504273504 and parameters: {'threshold': 'median', 'max_features': 594, 'norm_order': 1, 'learning_rate': 0.12021574442602004, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9889214958654, 'colsample_bytree': 0.6966683248889612, 'gamma': 0.8222493507936891, 'reg_alpha': 0.8977733846021244, 'reg_lambda': 4.149950456614802, 'n_estimators': 78}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:35,700] Trial 96 finished with value: 0.8671213843627635 and parameters: {'threshold': 'mean', 'max_features': 750, 'norm_order': 2, 'learning_rate': 0.249018707286543, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9635449261016953, 'colsample_bytree': 0.7189664334093677, 'gamma': 0.511190731893755, 'reg_alpha': 1.311543312155652, 'reg_lambda': 4.856367312179962, 'n_estimators': 97}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:36,505] Trial 97 finished with value: 0.8928115159694108 and parameters: {'threshold': '1.5*mean', 'max_features': 660, 'norm_order': 1, 'learning_rate': 0.09149796024076419, 'max_depth': 6, 'min_child_weight': 2, 'subsample': 0.982882163098953, 'colsample_bytree': 0.8272960760784138, 'gamma': 0.003980277200310078, 'reg_alpha': 0.56249375340536, 'reg_lambda': 3.8748731678199047, 'n_estimators': 55}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:37,215] Trial 98 finished with value: 0.7888888888888889 and parameters: {'threshold': '1.5*mean', 'max_features': 465, 'norm_order': 1, 'learning_rate': 0.08987047878742903, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.9748239365359544, 'colsample_bytree': 0.8277538602943358, 'gamma': 5.599876269570787, 'reg_alpha': 0.1674120444356877, 'reg_lambda': 3.2447715897504823, 'n_estimators': 56}. Best is trial 53 with value: 0.8952309472433311.
# Seed in the model 315491657 on Device cuda:0
# [I 2024-12-05 10:28:37,908] Trial 99 finished with value: 0.7214584886160322 and parameters: {'threshold': '1.5*mean', 'max_features': 758, 'norm_order': 1, 'learning_rate': 0.10811815892380072, 'max_depth': 8, 'min_child_weight': 3, 'subsample': 0.5538128864563079, 'colsample_bytree': 0.8478059674210633, 'gamma': 7.323987857377512, 'reg_alpha': 2.3389140843538145, 'reg_lambda': 3.859808706941446, 'n_estimators': 84}. Best is trial 53 with value: 0.8952309472433311.
# Best Parameters: {'threshold': 'mean', 'max_features': 620, 'norm_order': 2, 'learning_rate': 0.12243759368947355, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9736427801856483, 'colsample_bytree': 0.7318346177479617, 'gamma': 0.02524869265873242, 'reg_alpha': 1.7924682768446585, 'reg_lambda': 4.723542094454843, 'n_estimators': 61}
#
# Test Metrics:
# ROC AUC: 0.8756944444444444
# Accuracy: 0.7948717948717948
# F1 Score: 0.7647058823529411
# Confusion Matrix:
# [[36 12]
#  [ 4 26]]
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.75      0.82        48
#     Positive       0.68      0.87      0.76        30
#
#     accuracy                           0.79        78
#    macro avg       0.79      0.81      0.79        78
# weighted avg       0.82      0.79      0.80        78
#
# Number of selected features: 75
# Shape of SHAP values: (257, 75)
# Overlap bacteria found: {'GGB4566_SGB6305', 'Ruminococcaceae_unclassified_SGB15260', 'Sellimonas_intestinalis', 'Ruthenibacterium_lactatiformans', 'GGB9712_SGB15244', 'Clostridia_unclassified_SGB4367', 'Klebsiella_pneumoniae', 'Clostridium_sp_AT4', 'Tyzzerella_nexilis', 'Faecalibacterium_prausnitzii', 'Lachnospiraceae_bacterium', 'Bacteroides_stercoris', 'GGB3256_SGB4303', 'GGB3005_SGB3996', 'Alistipes_onderdonkii', 'Bacteroides_fragilis', 'GGB9557_SGB14966', 'Bacteroides_uniformis', 'Catabacter_hongkongensis', 'Dialister_invisus', 'Clostridia_unclassified_SGB4121', 'Blautia_massiliensis', 'Clostridia_bacterium', 'Streptococcus_salivarius', 'Roseburia_faecis', 'Ruminococcus_SGB4421', 'Clostridium_leptum', 'Collinsella_aerofaciens', 'Hungatella_hathewayi', 'Phocaeicola_dorei', 'Methanobrevibacter_smithii', 'Bacteroides_ovatus', 'Candidatus_Avimonas_narfia', 'Cloacibacillus_evryensis', 'Phocaeicola_vulgatus', 'Barnesiella_intestinihominis', 'Clostridium_symbiosum', 'Longicatena_caecimuris', 'Streptococcus_parasanguinis', 'Prevotella_pectinovora', 'Clostridium_sp_AF34_10BH', 'Clostridium_scindens', 'Alistipes_putredinis', 'Rikenellaceae_bacterium', 'Ruminococcus_gnavus', 'Escherichia_coli', 'Neglecta_timonensis', 'Lachnospiraceae_unclassified_SGB66069', 'Roseburia_hominis', 'Massilimicrobiota_sp_An134', 'Firmicutes_bacterium', 'Bacteroides_caccae', 'Bacteroides_xylanisolvens', 'Dorea_formicigenerans', 'Anaerobutyricum_hallii', 'Alistipes_finegoldii'}

# %%
auc
# Out:
# 0.8756944444444444

# %%
# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_test_pred)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')  # Dashed diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
accuracy
# Out:
# 0.7948717948717948

# %%
f1
# Out:
# 0.7647058823529411

# %%
conf_matrix
# Out:
# array([[36, 12],
#        [ 4, 26]], dtype=int64)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["Negative", "Positive"])
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
# Verify the selected feature names align with the SHAP values
assert len(selected_feature_names) == X_train_selected.shape[1], "Mismatch in feature names and SHAP input dimensions."

# Generate SHAP summary plot with corrected feature names
plt.figure(figsize=(20, 10))  # Increased width for a wider plot
plt.title("SHAP Violin Plot - Global Feature Importance", fontsize=14)

# Create summary plot with corrected feature names
shap.summary_plot(
    shap_values.values,  # SHAP values
    X_train_selected,  # Input data
    feature_names=selected_feature_names,  # Correct feature names
    max_display=20,  # Limit to top 20 features
    plot_type="violin"  # Violin plot with colors
)
plt.show()

bacteria_fount = check_for_bacteria(bacteria_df.species_name.tolist(),selected_feature_names)
# Out:
# Overlap bacteria found: {'GGB4566_SGB6305', 'Ruminococcaceae_unclassified_SGB15260', 'Sellimonas_intestinalis', 'Ruthenibacterium_lactatiformans', 'GGB9712_SGB15244', 'Clostridia_unclassified_SGB4367', 'Klebsiella_pneumoniae', 'Clostridium_sp_AT4', 'Tyzzerella_nexilis', 'Faecalibacterium_prausnitzii', 'Lachnospiraceae_bacterium', 'Bacteroides_stercoris', 'GGB3256_SGB4303', 'GGB3005_SGB3996', 'Alistipes_onderdonkii', 'Bacteroides_fragilis', 'GGB9557_SGB14966', 'Bacteroides_uniformis', 'Catabacter_hongkongensis', 'Dialister_invisus', 'Clostridia_unclassified_SGB4121', 'Blautia_massiliensis', 'Clostridia_bacterium', 'Streptococcus_salivarius', 'Roseburia_faecis', 'Ruminococcus_SGB4421', 'Clostridium_leptum', 'Collinsella_aerofaciens', 'Hungatella_hathewayi', 'Phocaeicola_dorei', 'Methanobrevibacter_smithii', 'Bacteroides_ovatus', 'Candidatus_Avimonas_narfia', 'Cloacibacillus_evryensis', 'Phocaeicola_vulgatus', 'Barnesiella_intestinihominis', 'Clostridium_symbiosum', 'Longicatena_caecimuris', 'Streptococcus_parasanguinis', 'Prevotella_pectinovora', 'Clostridium_sp_AF34_10BH', 'Clostridium_scindens', 'Alistipes_putredinis', 'Rikenellaceae_bacterium', 'Ruminococcus_gnavus', 'Escherichia_coli', 'Neglecta_timonensis', 'Lachnospiraceae_unclassified_SGB66069', 'Roseburia_hominis', 'Massilimicrobiota_sp_An134', 'Firmicutes_bacterium', 'Bacteroides_caccae', 'Bacteroides_xylanisolvens', 'Dorea_formicigenerans', 'Anaerobutyricum_hallii', 'Alistipes_finegoldii'}

# %%
# Ensure SHAP values are in the correct shape for processing
print(f"Shape of SHAP values: {shap_values.values.shape}")  # Check the shape

# Truncate each feature name to a maximum of 30 characters
max_len = 40
selected_feature_names = [
    feature[:max_len] if len(feature) > max_len else feature  # Truncate if longer than 30 characters
    for feature in selected_feature_names
]

# Verify the selected feature names align with the SHAP values
assert len(selected_feature_names) == X_train_selected.shape[1], "Mismatch in feature names and SHAP input dimensions."

# Generate SHAP summary plot with corrected feature names
plt.figure(figsize=(20, 10))  # Increased width for a wider plot
plt.title("SHAP Bar Plot - Global Feature Importance", fontsize=14)

# Create summary plot with corrected feature names
shap.summary_plot(
    shap_values.values,  # SHAP values
    X_train_selected,  # Input data
    feature_names=selected_feature_names,  # Correct feature names
    max_display=20,  # Limit to top 20 features
    plot_type="bar"  # Violin plot with colors
)
plt.show()

bacteria_fount = check_for_bacteria(bacteria_df.species_name.tolist(),selected_feature_names)
# Out:
# Shape of SHAP values: (257, 75)
# Overlap bacteria found: {'GGB4566_SGB6305', 'Ruminococcaceae_unclassified_SGB15260', 'Sellimonas_intestinalis', 'Ruthenibacterium_lactatiformans', 'GGB9712_SGB15244', 'Clostridia_unclassified_SGB4367', 'Klebsiella_pneumoniae', 'Clostridium_sp_AT4', 'Tyzzerella_nexilis', 'Faecalibacterium_prausnitzii', 'Lachnospiraceae_bacterium', 'Bacteroides_stercoris', 'GGB3256_SGB4303', 'GGB3005_SGB3996', 'Alistipes_onderdonkii', 'Bacteroides_fragilis', 'GGB9557_SGB14966', 'Bacteroides_uniformis', 'Catabacter_hongkongensis', 'Dialister_invisus', 'Clostridia_unclassified_SGB4121', 'Blautia_massiliensis', 'Clostridia_bacterium', 'Streptococcus_salivarius', 'Roseburia_faecis', 'Ruminococcus_SGB4421', 'Clostridium_leptum', 'Collinsella_aerofaciens', 'Hungatella_hathewayi', 'Phocaeicola_dorei', 'Methanobrevibacter_smithii', 'Bacteroides_ovatus', 'Candidatus_Avimonas_narfia', 'Cloacibacillus_evryensis', 'Phocaeicola_vulgatus', 'Barnesiella_intestinihominis', 'Clostridium_symbiosum', 'Longicatena_caecimuris', 'Streptococcus_parasanguinis', 'Prevotella_pectinovora', 'Clostridium_sp_AF34_10BH', 'Clostridium_scindens', 'Alistipes_putredinis', 'Rikenellaceae_bacterium', 'Ruminococcus_gnavus', 'Escherichia_coli', 'Neglecta_timonensis', 'Lachnospiraceae_unclassified_SGB66069', 'Roseburia_hominis', 'Massilimicrobiota_sp_An134', 'Firmicutes_bacterium', 'Bacteroides_caccae', 'Bacteroides_xylanisolvens', 'Dorea_formicigenerans', 'Anaerobutyricum_hallii', 'Alistipes_finegoldii'}

# %%
measures = ["xgboost", seed, experiment_number, accuracy, auc, f1]

# Create a DataFrame with appropriate column names
columns = ["Model", "Seed", "Experiment_Number", "Accuracy", "AUC", "F1_Score"]
measures_df = pd.DataFrame([measures], columns=columns)
measures_df
# Out:
#      Model       Seed  Experiment_Number  Accuracy       AUC  F1_Score
# 0  xgboost  315491657                  1  0.794872  0.875694  0.764706

# %%
output_path = "output"
measures_path = f"{output_path}{os.sep}xgboost_experiment{experiment_number:02d}_measures.csv"
if output_path and not os.path.exists(output_path):
    os.makedirs(output_path)
measures_path
# Out:
# 'output\\xgboost_experiment01_measures.csv'

# %%
measures_df.to_csv(measures_path, index=False)
